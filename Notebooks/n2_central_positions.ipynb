# %% [markdown]
# # Power and Influence: Central Positions in Networks

# %%
# %%capture
# Housekeeping
# As explained before, it is best practice to load the modules at the start
import networkx as nx
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
# This line allows visualizations within the notebook
# %matplotlib inline 
import matplotlib.gridspec as gridspec
import matplotlib.pylab as pl

# Make sure you download econ46_library.py from our course material and save it in the same folder as then notebooks
# this file has some functions specifically coded for the class
from supporting_material import econ46_library as el

# These modules are only to have some interactive pieces of code in the notebooks
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# ### Dutch High School Network
# Now, let's explore the social network of a high school class from the Netherlands. It was collected by Andrea Knech for a project on friendship selection and friendship influence.
#
# You have already seen how to create a network and look at some of its features. Here we will look at other ways to get the same information and will also expand our analysis.

# %%
# Load data with network information, list of edges in the network:
dutch_hs_dataframe = pd.read_csv('../Data/dutch_hs/dutch_class_t0.csv')

# Create a network using the adjancey matrix
G_hs = nx.from_pandas_edgelist(dutch_hs_dataframe)

# Visualize the network
el.plot_simple_graph(G_hs)

# %%
# List the nodes:
G_hs.nodes()
# Out:
# NodeView((0, 2, 5, 11, 8, 1, 6, 7, 9, 17, 23, 3, 22, 12, 13, 4, 15, 24, 10, 14, 20, 16, 21, 25, 18, 19))

# %%
# Counting the number of nodes is as simple as computing the length of the node list:
len(G_hs.nodes())
# Out:
# 26

# %%
# This time let's save the list of edges as an object and print  it instead of just running the command
edge_list = G_hs.edges()
print(edge_list)
# Out:
# [(0, 2), (0, 5), (0, 11), (0, 8), (2, 1), (2, 5), (2, 6), (2, 11), (2, 8), (5, 10), (5, 11), (5, 14), (5, 20), (5, 8), (5, 23), (11, 1), (11, 6), (11, 7), (11, 8), (11, 9), (11, 21), (8, 1), (8, 6), (8, 7), (8, 10), (8, 14), (8, 23), (1, 6), (1, 7), (1, 9), (1, 17), (1, 23), (6, 9), (6, 17), (7, 3), (7, 9), (7, 17), (7, 22), (9, 3), (9, 14), (9, 22), (9, 17), (17, 3), (17, 12), (17, 13), (17, 22), (3, 22), (3, 12), (3, 13), (22, 12), (22, 13), (12, 25), (13, 4), (13, 24), (4, 15), (4, 24), (15, 24), (10, 16), (10, 20), (16, 21), (21, 18), (21, 19), (18, 19)]

# %%
# Similarly we can compute the number of edges in the graph by calling the edges attribute of the G0 object
len(edge_list)
# Out:
# 63

# %% [markdown]
# With 26 nodes the network could have at most 26*(26-1)/2=325 edges.
#
# Since there are only 63 we can talk about how dense the network with respect to that fully connected or complete network.

# %%
density = 63/325
# Note how you can embbed the value of a variable into a line of text.
print('Density: %s' % density)
# Out:
# Density: 0.19384615384615383

# %% [markdown]
# ### Centrality Measures
# #### Degree  Distribution
#
# The **degree** of a node is the number of connections the node has.
#
# With networkx is very simple to take a look at the degree distribution.
#
# Each node has a degree attribute and they are all stored as a Dictionary, which means you can also query the degree of specific nodes by typing `G_hs.degree[node id]`:

# %%
# Degree attribute of a networkx network.
G_hs.degree
# Out:
# DegreeView({0: 4, 2: 6, 5: 8, 11: 9, 8: 10, 1: 8, 6: 6, 7: 7, 9: 8, 17: 8, 23: 3, 3: 6, 22: 6, 12: 4, 13: 5, 4: 3, 15: 2, 24: 3, 10: 4, 14: 3, 20: 2, 16: 2, 21: 4, 25: 1, 18: 2, 19: 2})

# %%
G_hs.degree([0,1])
# Out:
# DegreeView({0: 4, 1: 8})

# %%
G_hs.degree[8]
# Out:
# 10

# %%
# And we have a function in the class library to plot the distribution:
el.plot_centrality_dist(G_hs,'Degree Centrality')

# %% [markdown]
# #### Clustering
# The **clustering coefficient** represents the share of a node's connections that are connected to each other and is also readily available with networkx.

# %%
nx.clustering(G_hs)
# Out:
# {0: 1.0,
#  2: 0.7333333333333333,
#  5: 0.35714285714285715,
#  11: 0.4444444444444444,
#  8: 0.37777777777777777,
#  1: 0.5357142857142857,
#  6: 0.6666666666666666,
#  7: 0.5714285714285714,
#  9: 0.4642857142857143,
#  17: 0.5,
#  23: 0.6666666666666666,
#  3: 0.6666666666666666,
#  22: 0.6666666666666666,
#  12: 0.5,
#  13: 0.4,
#  4: 0.6666666666666666,
#  15: 1.0,
#  24: 0.6666666666666666,
#  10: 0.3333333333333333,
#  14: 0.3333333333333333,
#  20: 1.0,
#  16: 0,
#  21: 0.16666666666666666,
#  25: 0,
#  18: 1.0,
#  19: 1.0}

# %%
el.plot_centrality_dist(G_hs,'Clustering Centrality')

# %% [markdown]
# #### Betweenness Centrality

# %%
nx.betweenness_centrality(G_hs)
# Out:
# {0: 0.0,
#  2: 0.013928254980886559,
#  5: 0.08934920634920634,
#  11: 0.2870096492201755,
#  8: 0.14488042951200847,
#  1: 0.10222972933499253,
#  6: 0.056635972214919575,
#  7: 0.14570288386077862,
#  9: 0.12880443046232518,
#  17: 0.2284592892487629,
#  23: 0.0039270904534062425,
#  3: 0.07388146648672965,
#  22: 0.07388146648672965,
#  12: 0.08,
#  13: 0.22,
#  4: 0.03833333333333334,
#  15: 0.0,
#  24: 0.03833333333333334,
#  10: 0.05294627594627594,
#  14: 0.0141514012303486,
#  20: 0.0,
#  16: 0.015000000000000001,
#  21: 0.1858791208791209,
#  25: 0.0,
#  18: 0.0,
#  19: 0.0}

# %%
el.plot_centrality_dist(G_hs,'Betweenness Centrality')

# %% [markdown]
# Below you can interactively plot the network for different periods and observe how the different centrality measures reflect a node's position in the network.

# %%
display(el.dutch_nets,el.dutch_types,el.dutch_lays,el.dutch_atts,el.dutch_y)
# Out:
# ToggleButtons(description='Period:', options=('t=0', 't=1', 't=2', 't=3'), tooltips=('High School Classroom in…
# ToggleButtons(description='Types', options=('None', 'Reported Gender'), tooltips=('High School Classroom in th…
# ToggleButtons(description='Layout:', options=('Kamada Kawai', 'Circle', 'Spring', 'Random'), tooltips=('Circul…
# Dropdown(description='Attribute:', options=('', 'Degree Centrality', 'Clustering Centrality', 'Betweenness Cen…
# Output()

# %%
display(el.comp_accordion,el.comp_lays,el.comp_y)
# Out:
# Accordion(children=(VBox(children=(ToggleButtons(description='Network Type:', options=('Dutch High School', 'E…
# ToggleButtons(description='Layout:', options=('Circle', 'Kamada Kawai', 'Spring', 'Random'), tooltips=('Circul…
# Output()

# %%
G = el.read_network_from_file('../Data/dutch_hs/dutch_class_t0.csv')

# %%
G.nodes
# Out:
# NodeView((0, 2, 5, 11, 8, 1, 6, 7, 9, 17, 23, 3, 22, 12, 13, 4, 15, 24, 10, 14, 20, 16, 21, 25, 18, 19))

# %%
G = nx.read_pajek("imports_manufactures.net")

# %%
nx.is_directed(G)
# Out:
# True

# %%
adjacency_dataframe = nx.to_pandas_adjacency(G, dtype=int)

print(adjacency_dataframe)
# Out:
#                   Algeria  Argentina  Australia  Austria  Barbados  \
# Algeria                 0          0          0        0         0
# Argentina               0          0          0        0         0
# Australia               0          0          0        0         0
# Austria              3599          0      15533        0         0
# Barbados                0          0          0        0         0
# Bangladesh              0          0          0        0         0
# Belgium /Lux.       12994      10198          0    32959         0
# Belize                  0          0          0        0         0
# Bolivia                 0          0          0        0       517
# Brazil                  0     172885          0        0       231
# Canada                  0          0      13925        0       614
# Chile                   0      19116          0        0         0
# China               11709       9033      90620        0       312
# Colombia                0          0          0        0         0
# Croatia                 0          0          0        0         0
# Cyprus                  0          0          0        0         0
# Czech Rep.              0          0          0    40019         0
# Denmark                 0          0          0    20259       221
# Ecuador                 0          0          0        0         0
# Egypt                   0          0          0        0         0
# El Salvador             0          0          0        0         0
# Fiji                    0          0          0        0         0
# Finland                 0          0          0        0         0
# France Mon.         82104      29305      20979    45643         0
# French Guiana           0          0          0        0         0
# Germany             23436      29333      99820  1143072       341
# Greece                  0          0          0        0         0
# Guadeloupe              0          0          0        0         0
# Guatemala               0          0          0        0         0
# Honduras                0          0          0        0         0
# ...                   ...        ...        ...      ...       ...
# New Zealand             0          0      91691        0         0
# Nicaragua               0          0          0        0         0
# Norway                  0          0          0        0         0
# Oman                    0          0          0        0         0
# Pakistan                0          0          0        0         0
# Panama                  0          0          0        0         0
# Paraguay                0          0          0        0         0
# Peru                    0          0          0        0         0
# Philippines             0          0          0        0         0
# Poland                  0          0          0        0         0
# Portugal                0          0          0        0         0
# Moldava. Rep. Of        0          0          0        0         0
# Reunion                 0          0          0        0         0
# Romania                 0          0          0        0         0
# Seychelles              0          0          0        0         0
# Singapore               0          0      19856        0         0
# Slovenia                0          0          0    25786         0
# Southern Africa         0          0          0        0         0
# Spain                8017      20995          0        0         0
# Sri Lanka               0          0          0        0         0
# Sweden                  0      10327      32204    22120         0
# Switzerland             0          0      20560   130434         0
# Thailand                0          0      14377        0         0
# Trinidad Tobago         0          0          0        0      1061
# Tunisia              6283          0          0        0         0
# Turkey               7761          0          0        0         0
# United Kingdom       6183       9988      82737    28793      3574
# United States       40151     147671     250407    37419     11210
# Uruguay                 0          0          0        0         0
# Venezuela               0          0          0        0         0
#
#                   Bangladesh  Belgium /Lux.  Belize  Bolivia  Brazil  ...  \
# Algeria                    0              0       0        0       0  ...
# Argentina                  0              0       0     2037   13898  ...
# Australia                304              0       0        0       0  ...
# Austria                    0          36169       0        0       0  ...
# Barbados                   0              0     502        0       0  ...
# Bangladesh                 0              0       0        0       0  ...
# Belgium /Lux.              0              0       0        0    5043  ...
# Belize                     0              0       0        0       0  ...
# Bolivia                    0              0       0        0       0  ...
# Brazil                     0              0     193    15609       0  ...
# Canada                     0              0     210        0       0  ...
# Chile                      0              0       0     4114       0  ...
# China                   5217          30181     493     1296       0  ...
# Colombia                   0              0       0     1596       0  ...
# Croatia                    0              0       0        0       0  ...
# Cyprus                     0              0       0        0       0  ...
# Czech Rep.                 0              0       0        0       0  ...
# Denmark                    0          30876       0        0       0  ...
# Ecuador                    0              0       0        0       0  ...
# Egypt                      0              0       0        0       0  ...
# El Salvador                0              0       0        0       0  ...
# Fiji                       0              0       0        0       0  ...
# Finland                    0              0       0        0       0  ...
# France Mon.                0         523392       0        0   28613  ...
# French Guiana              0              0       0        0       0  ...
# Germany                 2205         798074       0     1711   76524  ...
# Greece                     0              0       0        0       0  ...
# Guadeloupe                 0              0       0        0       0  ...
# Guatemala                  0              0     399        0       0  ...
# Honduras                   0              0       0        0       0  ...
# ...                      ...            ...     ...      ...     ...  ...
# New Zealand                0              0       0        0       0  ...
# Nicaragua                  0              0       0        0       0  ...
# Norway                     0              0       0        0       0  ...
# Oman                       0              0       0        0       0  ...
# Pakistan                   0              0       0        0       0  ...
# Panama                     0              0       0        0       0  ...
# Paraguay                   0              0       0        0       0  ...
# Peru                       0              0       0     3397       0  ...
# Philippines                0              0       0        0       0  ...
# Poland                     0              0       0        0       0  ...
# Portugal                   0              0       0        0       0  ...
# Moldava. Rep. Of           0              0       0        0       0  ...
# Reunion                    0              0       0        0       0  ...
# Romania                    0              0       0        0       0  ...
# Seychelles                 0              0       0        0       0  ...
# Singapore                833              0       0        0       0  ...
# Slovenia                   0              0       0        0       0  ...
# Southern Africa            0              0       0        0       0  ...
# Spain                      0          40454     558     1528    4659  ...
# Sri Lanka                  0              0       0        0       0  ...
# Sweden                     0          43088       0      575   15059  ...
# Switzerland                0          61176     254        0    7603  ...
# Thailand                   0              0       0        0       0  ...
# Trinidad Tobago            0              0     151        0       0  ...
# Tunisia                    0              0       0        0       0  ...
# Turkey                     0              0       0        0       0  ...
# United Kingdom             0         109144    1067        0    9428  ...
# United States           1195          94976    7062    11062  169859  ...
# Uruguay                    0              0       0        0       0  ...
# Venezuela                  0              0       0     1503       0  ...
#
#                   Sweden  Switzerland  Thailand  Trinidad Tobago  Tunisia  \
# Algeria                0            0         0                0        0
# Argentina              0            0         0                0        0
# Australia              0            0         0                0        0
# Austria            29524       159097         0                0     1421
# Barbados               0            0         0             4491        0
# Bangladesh             0            0         0                0        0
# Belgium /Lux.      23430        31829         0                0     6130
# Belize                 0            0         0                0        0
# Bolivia                0            0         0                0        0
# Brazil                 0            0         0              936        0
# Canada                 0            0         0             1126        0
# Chile                  0            0         0                0        0
# China              23543            0     44387             1494     2539
# Colombia               0            0         0                0        0
# Croatia                0            0         0                0        0
# Cyprus                 0            0         0                0        0
# Czech Rep.             0            0         0                0        0
# Denmark           121647        34693         0                0        0
# Ecuador                0            0         0                0        0
# Egypt                  0            0         0                0     2153
# El Salvador            0            0         0                0        0
# Fiji                   0            0         0                0        0
# Finland           108793            0         0                0        0
# France Mon.        68207       184576         0                0    41597
# French Guiana          0            0         0                0        0
# Germany           437006       970830     58662              835    15582
# Greece                 0            0         0                0        0
# Guadeloupe             0            0         0                0        0
# Guatemala              0            0         0                0        0
# Honduras               0            0         0                0        0
# ...                  ...          ...       ...              ...      ...
# New Zealand            0            0         0                0        0
# Nicaragua              0            0         0                0        0
# Norway             83159            0         0                0        0
# Oman                   0            0         0                0        0
# Pakistan               0            0         0                0        0
# Panama                 0            0         0                0        0
# Paraguay               0            0         0                0        0
# Peru                   0            0         0                0        0
# Philippines            0            0         0                0        0
# Poland             18936            0         0                0        0
# Portugal           15812            0         0                0        0
# Moldava. Rep. Of       0            0         0                0        0
# Reunion                0            0         0                0        0
# Romania                0            0         0                0        0
# Seychelles             0            0         0                0        0
# Singapore              0            0     81685                0        0
# Slovenia               0            0         0                0        0
# Southern Africa        0            0         0                0        0
# Spain                  0            0         0                0     4650
# Sri Lanka              0            0         0                0        0
# Sweden                 0            0         0                0        0
# Switzerland        45523            0         0                0        0
# Thailand               0            0         0                0        0
# Trinidad Tobago        0            0         0                0        0
# Tunisia                0            0         0                0        0
# Turkey                 0            0         0                0     6054
# United Kingdom    124480        46636     28510             4784     2560
# United States      70568        47707    181924            23795     7717
# Uruguay                0            0         0                0        0
# Venezuela              0            0         0             1401        0
#
#                   Turkey  United Kingdom  United States  Uruguay  Venezuela
# Algeria                0               0              0        0          0
# Argentina              0               0              0     7854          0
# Australia              0               0              0        0          0
# Austria             5957           96667              0        0          0
# Barbados               0               0              0        0          0
# Bangladesh             0               0              0        0          0
# Belgium /Lux.      12629          130180              0        0       4057
# Belize                 0               0              0        0          0
# Bolivia                0               0              0        0          0
# Brazil                 0               0         140405    26605       8052
# Canada                 0               0        2032121        0       2133
# Chile                  0               0              0     1482          0
# China               4800          114947        1066964     2057          0
# Colombia               0               0              0        0       9711
# Croatia                0               0              0        0          0
# Cyprus                 0               0              0        0          0
# Czech Rep.             0               0              0        0          0
# Denmark                0           87959              0        0          0
# Ecuador                0               0              0        0          0
# Egypt                  0               0              0        0          0
# El Salvador            0               0              0        0          0
# Fiji                   0               0              0        0          0
# Finland                0               0              0        0          0
# France Mon.        58815          306259         328783     1442       2197
# French Guiana          0               0              0        0          0
# Germany            90816          882784         781766     1855      13060
# Greece                 0               0              0        0          0
# Guadeloupe             0               0              0        0          0
# Guatemala              0               0              0        0          0
# Honduras               0               0              0        0          0
# ...                  ...             ...            ...      ...        ...
# New Zealand            0               0              0        0          0
# Nicaragua              0               0              0        0          0
# Norway                 0               0              0        0          0
# Oman                   0               0              0        0          0
# Pakistan               0               0              0        0          0
# Panama                 0               0              0        0          0
# Paraguay               0               0              0        0          0
# Peru                   0               0              0        0          0
# Philippines            0               0              0        0          0
# Poland                 0               0              0        0          0
# Portugal               0               0              0        0          0
# Moldava. Rep. Of       0               0              0        0          0
# Reunion                0               0              0        0          0
# Romania                0               0              0        0          0
# Seychelles             0               0              0        0          0
# Singapore              0               0              0        0          0
# Slovenia               0               0              0        0          0
# Southern Africa        0               0              0        0          0
# Spain               5510           84460              0     3479       6272
# Sri Lanka              0               0              0        0          0
# Sweden              5582          131895         153074        0       3286
# Switzerland         6227          160542         221690        0          0
# Thailand               0               0              0        0          0
# Trinidad Tobago        0               0              0        0          0
# Tunisia                0               0              0        0          0
# Turkey                 0               0              0        0          0
# United Kingdom     25310               0         355999      984       4397
# United States      19258          469992              0     4898      93511
# Uruguay                0               0              0        0          0
# Venezuela              0               0              0        0          0
#
# [80 rows x 80 columns]

# %%
nx.betweenness_centrality(G)
# Out:
# {'Algeria': 0.0,
#  'Argentina': 0.10985180026075839,
#  'Australia': 0.014753628432819684,
#  'Austria': 0.010463073674967103,
#  'Barbados': 0.0009607246949019098,
#  'Bangladesh': 0.0,
#  'Belgium /Lux.': 0.006449872458244738,
#  'Belize': 0.0,
#  'Bolivia': 0.0022009379239174755,
#  'Brazil': 0.12282668824232869,
#  'Canada': 0.0014279397799358848,
#  'Chile': 0.10514361895812721,
#  'China': 0.009355441015014456,
#  'Colombia': 0.0890091332871561,
#  'Croatia': 0.00045052347107387347,
#  'Cyprus': 0.0,
#  'Czech Rep.': 0.00042398936469556053,
#  'Denmark': 0.006906750194497704,
#  'Ecuador': 0.07992889084661235,
#  'Egypt': 0.00030473691622669223,
#  'El Salvador': 0.059034118198446055,
#  'Fiji': 0.0,
#  'Finland': 0.001242262177201872,
#  'France Mon.': 0.007127573711125851,
#  'French Guiana': 0.0,
#  'Germany': 0.05921458893113504,
#  'Greece': 0.01219952592396604,
#  'Guadeloupe': 0.0,
#  'Guatemala': 0.01398180419602036,
#  'Honduras': 0.023564421982143497,
#  'Hong Kong': 0.003128537135790983,
#  'Hungary': 0.0020402535661203786,
#  'Iceland': 0.0,
#  'India': 0.013311794092371926,
#  'Indonesia': 0.0019600593967682572,
#  'Ireland': 0.0,
#  'Israel': 0.0011408048116908875,
#  'Italy': 0.022289388405913702,
#  'Japan': 0.04642891237644282,
#  'Jordan': 0.0,
#  'Korea. Rep. Of': 0.0032084813958738125,
#  'Kuwait': 0.0,
#  'Latvia': 0.0,
#  'Madagascar': 0.0,
#  'Malaysia': 0.0030457216638651234,
#  'Martinique': 0.0,
#  'Mauritius': 0.0,
#  'Mexico': 0.0017122558132925273,
#  'Morocco': 0.0,
#  'Netherlands': 0.007213848121730309,
#  'New Zealand': 0.0003863342470937408,
#  'Nicaragua': 0.0,
#  'Norway': 0.0004902237634763777,
#  'Oman': 0.0,
#  'Pakistan': 0.0,
#  'Panama': 0.06943010046638548,
#  'Paraguay': 0.0,
#  'Peru': 0.0041315973750534725,
#  'Philippines': 0.0,
#  'Poland': 0.0014603087654688246,
#  'Portugal': 4.856254856254856e-05,
#  'Moldava. Rep. Of': 0.0,
#  'Reunion': 0.0,
#  'Romania': 0.002051104721119583,
#  'Seychelles': 0.0,
#  'Singapore': 0.009594652979392463,
#  'Slovenia': 0.012725846586606077,
#  'Southern Africa': 0.008813774924113128,
#  'Spain': 0.009289807003647493,
#  'Sri Lanka': 0.0,
#  'Sweden': 0.031277169092916036,
#  'Switzerland': 0.002886266512738957,
#  'Thailand': 0.0002900209651264503,
#  'Trinidad Tobago': 0.0005389711085913617,
#  'Tunisia': 0.0005178365937859609,
#  'Turkey': 0.0005162655307958139,
#  'United Kingdom': 0.03140792327410686,
#  'United States': 0.14607033331006627,
#  'Uruguay': 0.0,
#  'Venezuela': 0.004121983490074445}
